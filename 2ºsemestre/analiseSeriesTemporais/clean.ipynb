# %%
import pandas as pd
import numpy as np

# %%
df_a = pd.read_csv('dataset.csv',encoding='mbcs',header=None)   
df_b = pd.read_csv('header.csv',sep=";",encoding='mbcs',header=None)   
df_c = pd.concat([df_b, df_a], axis=0)
# Out:
# C:\Users\GONCA\AppData\Local\Temp\ipykernel_8756\1538530644.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_a = pd.read_csv('dataset.csv',encoding='mbcs',header=None)

# %%
df_c
# Out:
#                                                         0               1   \
# 0        iscteid;referencia;cpostaldestino;cliente;loca...             NaN
# 0                                                        2             NaN
# 1                                                        3  29860138252642
# 2                                                        4             NaN
# 3                                                        5  29860138237939
# ...                                                    ...             ...
# 1132307                                             188436    PRZ/65761326
# 1132308                                             173076    PRZ/65764524
# 1132309                                             303227    PRZ/65792184
# 1132310                                             160703    PRZ/65727492
# 1132311                                             132864   F003250005906
#
# ...
